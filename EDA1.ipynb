# %%
# EDA on Cardiotocographic Dataset

# 📦 Step 1: Import Required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns



# 📥 Step 2: Load the Dataset
df = pd.read_csv("Cardiotocographic.csv")  # Make sure this file is in the same directory
df.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %% [markdown]
# ### 🧹 Step 3: Data Cleaning & Preparation
#
# We'll now check for missing values, data types, and clean the dataset if necessary.

# %%
# Check for missing values
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
# Convert columns to numeric (in case there are some wrong types)
df = df.apply(pd.to_numeric, errors='coerce')

# Drop rows with NaN (after coercion)
df.dropna(inplace=True)

# Final dataset shape
df.shape
# Out:
# (2105, 14)

# %% [markdown]
# ### 🧮 Step 4: Statistical Summary
#
# Let's now see the basic statistics of each variable — mean, median, std, etc.

# %%
# Statistical description
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2105.000000  2105.000000  2105.000000  2105.000000
# mean    133.343598     0.003202     0.009963     0.004388     0.001892
# std      11.270154     0.004324     0.067870     0.003350     0.003348
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001838     0.000000
# 50%     133.000000     0.001631     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002554     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2105.000000  2105.000000  2105.000000
# mean      0.000003     0.000175    46.996929     1.361006    10.353647
# std       0.000142     0.000840    18.847737     1.173164    21.282102
# ...

# %% [markdown]
# ### 📊 Step 5: Data Visualization – Histograms
#
# We'll now plot histograms to see distribution of each numerical feature.

# %%
# Plot histograms
df.hist(figsize=(15, 12), bins=20, color='skyblue', edgecolor='black')
plt.suptitle("Histograms of All Features", fontsize=18)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 📦 Step 6: Outlier Detection – Boxplots

# %%
# Boxplots to detect outliers
plt.figure(figsize=(15, 10))
sns.boxplot(data=df)
plt.title("Boxplots of All Features")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### 🔥 Step 7: Correlation Analysis – Heatmap

# %%
# Heatmap of correlations
plt.figure(figsize=(14, 10))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ### 🧪 Step 8: Pairplot for Visual Patterns

# %%
# Pairplot (only first 5 columns for simplicity)
sns.pairplot(df[df.columns[:5]])
plt.suptitle("Pairplot of Selected Features", y=1.02)
plt.show()

# %% [markdown]
# ### 🎻 Step 9: Violin Plot

# %%
# Violin plot for selected columns
plt.figure(figsize=(10, 6))
sns.violinplot(data=df[['LB', 'AC', 'FM']])
plt.title("Violin Plot of LB, AC, FM")
plt.show()

# %% [markdown]
# ### 💡 Step 10: Insights
#
# - LB (Baseline Heart Rate) is approximately normally distributed.
# - Some features like `UC`, `DL`, and `DP` show outliers.
# - Strong correlation between `ASTV` and `ALTV`.
# - Dataset is clean and ready for modeling.
#
# ---

# %% [markdown]
# ### ✅ Step 11: Conclusion
#
# - The dataset shows useful patterns and feature relationships.
# - Data is mostly clean and well-behaved.
# - This EDA is useful for fetal health prediction models.
